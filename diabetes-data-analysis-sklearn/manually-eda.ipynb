# %% [markdown]
# ## **Perform EDA for first 10 rows manually**

# %% [markdown]
# ### **Importing libraries and dataset**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_diabetes

# %% [markdown]
# - ***Loading data set***

# %%
diabetes = load_diabetes()

# %% [markdown]
# - ***Converting data into Dataframe***

# %%
df = pd.DataFrame(diabetes.data, columns=diabetes.feature_names)

# %% [markdown]
# - ***adding y label as target***

# %%
df['target'] = diabetes.target

# %% [markdown]
# - ***Taking first 10 rows from data set***

# %%
df_10 = df.head(10)

# %%
df_10
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5 -0.092695 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# 6 -0.045472  0.050680 -0.047163 -0.015999 -0.040096 -0.024800  0.000779
# 7  0.063504  0.050680 -0.001895  0.066629  0.090620  0.108914  0.022869
# 8  0.041708  0.050680  0.061696 -0.040099 -0.013953  0.006202 -0.028674
# 9 -0.070900 -0.044642  0.039062 -0.033213 -0.012577 -0.034508 -0.024993
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# ...

# %% [markdown]
# - ***rows & columns count***

# %%
df_10.shape
# Out:
# (10, 11)

# %% [markdown]
# - ***column names***

# %%
df_10.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6',
#        'target'],
#       dtype='object')

# %% [markdown]
# - ***Idea for data types and missing values***

# %%
df_10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     10 non-null     float64
#  1   sex     10 non-null     float64
#  2   bmi     10 non-null     float64
#  3   bp      10 non-null     float64
#  4   s1      10 non-null     float64
#  5   s2      10 non-null     float64
#  6   s3      10 non-null     float64
#  7   s4      10 non-null     float64
#  8   s5      10 non-null     float64
#  9   s6      10 non-null     float64
#  10  target  10 non-null     float64
# dtypes: float64(11)
# memory usage: 1012.0 bytes

# %% [markdown]
# - ***mean, std, min, max(etc.) for numerical columns***

# %%
df_10.describe()
# Out:
#              age        sex        bmi         bp         s1         s2  \
# count  10.000000  10.000000  10.000000  10.000000  10.000000  10.000000
# mean   -0.006604   0.003019   0.001770  -0.006703  -0.012714  -0.007107
# std     0.064733   0.050239   0.046038   0.033930   0.044204   0.050668
# min    -0.092695  -0.044642  -0.051474  -0.040099  -0.068991  -0.079288
# 25%    -0.064543  -0.044642  -0.039618  -0.031492  -0.043192  -0.034429
# 50%     0.001751   0.003019  -0.006745  -0.017720  -0.013265  -0.021982
# 75%     0.040800   0.050680   0.043104   0.014987   0.000839   0.013248
# max     0.085299   0.050680   0.061696   0.066629   0.090620   0.108914
#
#               s3         s4         s5         s6      target
# count  10.000000  10.000000  10.000000  10.000000   10.000000
# mean   -0.001798  -0.011633  -0.014199  -0.032558  142.600000
# std     0.038693   0.031844   0.042615   0.036852   71.680154
# min    -0.043401  -0.076395  -0.068332  -0.096346   63.000000
# ...

# %% [markdown]
# - ***Checking for null values***

# %%
df_10.isnull().sum()
# Out:
# age       0
# sex       0
# bmi       0
# bp        0
# s1        0
# s2        0
# s3        0
# s4        0
# s5        0
# s6        0
# target    0
# dtype: int64

# %% [markdown]
# - ***Unique values and variation***

# %%
df_10.nunique()
# Out:
# age       10
# sex        2
# bmi        9
# bp         9
# s1        10
# s2        10
# s3        10
# s4         5
# s5        10
# s6        10
# target    10
# dtype: int64

# %% [markdown]
# - ***Checking correlation between numerical features***

# %%
df_10.corr()
# Out:
#              age       sex       bmi        bp        s1        s2        s3  \
# age     1.000000  0.703896  0.476920  0.545429  0.264860  0.382175 -0.144222
# sex     0.703896  1.000000  0.503429  0.374358  0.049216  0.236486 -0.391156
# bmi     0.476920  0.503429  1.000000 -0.010769 -0.065797 -0.008987 -0.767084
# bp      0.545429  0.374358 -0.010769  1.000000  0.540699  0.580274  0.113606
# s1      0.264860  0.049216 -0.065797  0.540699  1.000000  0.962679  0.132389
# s2      0.382175  0.236486 -0.008987  0.580274  0.962679  1.000000  0.009834
# s3     -0.144222 -0.391156 -0.767084  0.113606  0.132389  0.009834  1.000000
# s4      0.323076  0.189331  0.480281  0.245818  0.633255  0.686174 -0.617639
# s5     -0.121764 -0.098579  0.705594 -0.191659 -0.036189 -0.099248 -0.755133
# s6      0.373671  0.544999  0.706212  0.178934  0.462364  0.562530 -0.764309
# target -0.460339 -0.323521  0.344088 -0.416376 -0.158424 -0.256838 -0.586689
#
# ...

# %% [markdown]
# - ***Visual representation of correlation***

# %%
sns.heatmap(df_10.corr(), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# ### **Visualization manually**

# %% [markdown]
# #### ***Histogram***
# - **Numerical data distribution**

# %%
df_10.hist(figsize=(10,10))
# Out:
# array([[<Axes: title={'center': 'age'}>, <Axes: title={'center': 'sex'}>,
#         <Axes: title={'center': 'bmi'}>],
#        [<Axes: title={'center': 'bp'}>, <Axes: title={'center': 's1'}>,
#         <Axes: title={'center': 's2'}>],
#        [<Axes: title={'center': 's3'}>, <Axes: title={'center': 's4'}>,
#         <Axes: title={'center': 's5'}>],
#        [<Axes: title={'center': 's6'}>,
#         <Axes: title={'center': 'target'}>, <Axes: >]], dtype=object)

# %% [markdown]
# #### ***Box plot***
# - **Understanding of outliers**

# %%
sns.boxplot(data=df_10)
# Out:
# <Axes: >

# %% [markdown]
# #### ***Pairplot***
# - **Relation between features**

# %%
sns.pairplot(df_10)

# %% [markdown]
# ### **Scatter Plot (BMI vs Target)**

# %%
sns.scatterplot(x='bmi', y='target', data=df_10)
# Out:
# <Axes: xlabel='bmi', ylabel='target'>
